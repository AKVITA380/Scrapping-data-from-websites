# %% [markdown]
# import pandas as pd
# # how to scrapping data

# %%
url = "https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"

# %%
tables = pd.read_html(url)

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 1

# %%
fundraising = tables[0]

# %%
fundraising
# Out:
#          Year Source       Revenue      Expenses   Asset rise  \
# 0   2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1   2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2   2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3   2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4   2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
# 5   2017/2018    PDF  $104,505,783   $81,442,265  $21,619,373
# 6   2016/2017    PDF   $91,242,418   $69,136,758  $21,547,402
# 7   2015/2016    PDF   $81,862,724   $65,947,465  $13,962,497
# 8   2014/2015    PDF   $75,797,223   $52,596,782  $24,345,277
# 9   2013/2014    PDF   $52,465,287   $45,900,745   $8,285,897
# 10  2012/2013    PDF   $48,635,408   $35,704,796  $10,260,066
# 11  2011/2012    PDF   $38,479,665   $29,260,652  $10,736,914
# 12  2010/2011    PDF   $24,785,092   $17,889,794   $9,649,413
# 13  2009/2010    PDF   $17,979,312   $10,266,793   $6,310,964
# ...

# %%
fundraising.head()
# Out:
#         Year Source       Revenue      Expenses   Asset rise  \
# 0  2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1  2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2  2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3  2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4  2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
#
#   Net assets at end of year
# 0              $254,971,336
# 1              $239,351,532
# 2              $231,177,536
# 3              $180,315,725
# 4              $165,641,425

# %%
type(fundraising)
# Out:
# pandas.core.frame.DataFrame

# %%
fundraising.dtypes
# Out:
# Year                         object
# Source                       object
# Revenue                      object
# Expenses                     object
# Asset rise                   object
# Net assets at end of year    object
# dtype: object

# %%
fundraising['Rev']= fundraising['Revenue'].str[2:] # Remove the $ sign Revenue

# %%
fundraising
# Out:
#          Year Source       Revenue      Expenses   Asset rise  \
# 0   2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1   2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2   2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3   2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4   2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
# 5   2017/2018    PDF  $104,505,783   $81,442,265  $21,619,373
# 6   2016/2017    PDF   $91,242,418   $69,136,758  $21,547,402
# 7   2015/2016    PDF   $81,862,724   $65,947,465  $13,962,497
# 8   2014/2015    PDF   $75,797,223   $52,596,782  $24,345,277
# 9   2013/2014    PDF   $52,465,287   $45,900,745   $8,285,897
# 10  2012/2013    PDF   $48,635,408   $35,704,796  $10,260,066
# 11  2011/2012    PDF   $38,479,665   $29,260,652  $10,736,914
# 12  2010/2011    PDF   $24,785,092   $17,889,794   $9,649,413
# 13  2009/2010    PDF   $17,979,312   $10,266,793   $6,310,964
# ...

# %%
fundraising.head()
# Out:
#         Year Source       Revenue      Expenses   Asset rise  \
# 0  2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1  2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2  2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3  2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4  2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
#
#   Net assets at end of year         Rev
# 0              $254,971,336  80,174,103
# 1              $239,351,532  54,686,521
# 2              $231,177,536  62,886,686
# 3              $180,315,725  29,234,327
# 4              $165,641,425  20,067,266

# %%
fundraising['Rev']= fundraising['Rev'].str.replace(',', ' ')

# %%
fundraising.head()
# Out:
#         Year Source       Revenue      Expenses   Asset rise  \
# 0  2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1  2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2  2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3  2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4  2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
#
#   Net assets at end of year         Rev
# 0              $254,971,336  80 174 103
# 1              $239,351,532  54 686 521
# 2              $231,177,536  62 886 686
# 3              $180,315,725  29 234 327
# 4              $165,641,425  20 067 266

# %%
fundraising.tail()
# Out:
#          Year Source     Revenue    Expenses  Asset rise  \
# 15  2007/2008    PDF  $5,032,981  $3,540,724  $3,519,886
# 16  2006/2007    PDF  $2,734,909  $2,077,843    $654,066
# 17  2005/2006    PDF  $1,508,039    $791,907    $736,132
# 18  2004/2005    PDF    $379,088    $177,670    $211,418
# 19  2003/2004    PDF     $80,129     $23,463     $56,666
#
#    Net assets at end of year       Rev
# 15                $5,178,168   032 981
# 16                $1,658,282   734 909
# 17                $1,004,216   508 039
# 18                  $268,084    79 088
# 19                   $56,666     0 129

# %%
fundraising.shape
# Out:
# (20, 7)

# %%
fundraising.dtypes
# Out:
# Year                         object
# Source                       object
# Revenue                      object
# Expenses                     object
# Asset rise                   object
# Net assets at end of year    object
# Rev                          object
# dtype: object

# %%
fundraising['Expen']= fundraising['Expenses'].str[2:]

# %%
fundraising
# Out:
#          Year Source       Revenue      Expenses   Asset rise  \
# 0   2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1   2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2   2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3   2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4   2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
# 5   2017/2018    PDF  $104,505,783   $81,442,265  $21,619,373
# 6   2016/2017    PDF   $91,242,418   $69,136,758  $21,547,402
# 7   2015/2016    PDF   $81,862,724   $65,947,465  $13,962,497
# 8   2014/2015    PDF   $75,797,223   $52,596,782  $24,345,277
# 9   2013/2014    PDF   $52,465,287   $45,900,745   $8,285,897
# 10  2012/2013    PDF   $48,635,408   $35,704,796  $10,260,066
# 11  2011/2012    PDF   $38,479,665   $29,260,652  $10,736,914
# 12  2010/2011    PDF   $24,785,092   $17,889,794   $9,649,413
# 13  2009/2010    PDF   $17,979,312   $10,266,793   $6,310,964
# ...

# %%
fundraising['Expen']= fundraising['Expen'].str.replace(',', ' ')

# %%
fundraising
# Out:
#          Year Source       Revenue      Expenses   Asset rise  \
# 0   2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1   2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2   2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3   2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4   2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
# 5   2017/2018    PDF  $104,505,783   $81,442,265  $21,619,373
# 6   2016/2017    PDF   $91,242,418   $69,136,758  $21,547,402
# 7   2015/2016    PDF   $81,862,724   $65,947,465  $13,962,497
# 8   2014/2015    PDF   $75,797,223   $52,596,782  $24,345,277
# 9   2013/2014    PDF   $52,465,287   $45,900,745   $8,285,897
# 10  2012/2013    PDF   $48,635,408   $35,704,796  $10,260,066
# 11  2011/2012    PDF   $38,479,665   $29,260,652  $10,736,914
# 12  2010/2011    PDF   $24,785,092   $17,889,794   $9,649,413
# 13  2009/2010    PDF   $17,979,312   $10,266,793   $6,310,964
# ...

# %%
fundraising.head()
# Out:
#         Year Source       Revenue      Expenses   Asset rise  \
# 0  2022/2023    PDF  $180,174,103  $169,095,381  $15,619,804
# 1  2021/2022    PDF  $154,686,521  $145,970,915   $8,173,996
# 2  2020/2021    PDF  $162,886,686  $111,839,819  $50,861,811
# 3  2019/2020    PDF  $129,234,327  $112,489,397  $14,674,300
# 4  2018/2019    PDF  $120,067,266   $91,414,010  $30,691,855
#
#   Net assets at end of year         Rev       Expen
# 0              $254,971,336  80 174 103  69 095 381
# 1              $239,351,532  54 686 521  45 970 915
# 2              $231,177,536  62 886 686  11 839 819
# 3              $180,315,725  29 234 327  12 489 397
# 4              $165,641,425  20 067 266   1 414 010

# %%
fundraising.dtypes
# Out:
# Year                         object
# Source                       object
# Revenue                      object
# Expenses                     object
# Asset rise                   object
# Net assets at end of year    object
# Rev                          object
# Expen                        object
# dtype: object
