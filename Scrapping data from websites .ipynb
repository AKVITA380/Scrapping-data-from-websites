# %% [markdown]
# Scrapping data from websites using Python can be quite powerful. You can use libraries like BeautifulSoup or
# Scrapy to make the process easier. BeautifulSoup is great for simpler tasks, while Scrapy is more robust for larger projects

# %% [markdown]
# Install Libraries: First, you need to install BeautifulSoup or pip install requests. You can do this using pip:

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Inspect the Website:
# Before you start coding, inspect the website you want to scrape. Identify the elements containing the data you need.
# Write the Code: Using BeautifulSoup

# %%
import sys 
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    page=requests.get('https://www.cricbuzz.com/')
except Exception as e:
        error_type,error_obj, error_info = sys.exc_info()
        print("ERROR FOR LINK:",url)
        print(error_type,'line:',error_info.tb_linebo)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# Run the Code: Execute your Python script and check the output

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# SRH notched up the highest team total inside ten overs as they made light work of the chase
#
#
# The loser of this fixture will stand eliminated from the IPL 2024 playoffs race
#
#
# Virat Kohli's 42 (27) against Gujarat Titans makes it to our 'Carrier Room Air Conditioners Coolest Moment of the Match'. Joy Bhattacharjya & Shaun Pollock discuss, on Cricbuzz Live
#
#
# Both of India's selected wicketkeepers were in an unsaid shoot-out at the DC vs RR game on Tuesday but the decision for Rohit Sharma may not be so simple
#
#
# The South Africa men's team continues to battle with serious issues that are now systemic
#
#
# Former Australian fast bowler Ryan Harris talks about the tough life bowlers face in the IPL and what they need to bounce back in the hostile situation they find themselves in
#
#
# Soumya Sarkar has recovered from his knee injury and also features in the 15-man squad
#
#
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">SRH notched up the highest team total inside ten overs as they made light work of the chase</div>,
#  <div class="cb-nws-intr">The loser of this fixture will stand eliminated from the IPL 2024 playoffs race</div>,
#  <div class="cb-nws-intr">Virat Kohli's 42 (27) against Gujarat Titans makes it to our 'Carrier Room Air Conditioners Coolest Moment of the Match'. Joy Bhattacharjya &amp; Shaun Pollock discuss, on Cricbuzz Live</div>,
#  <div class="cb-nws-intr">Both of India's selected wicketkeepers were in an unsaid shoot-out at the DC vs RR game on Tuesday but the decision for Rohit Sharma may not be so simple</div>,
#  <div class="cb-nws-intr">The South Africa men's team continues to battle with serious issues that are now systemic</div>,
#  <div class="cb-nws-intr">Former Australian fast bowler Ryan Harris talks about the tough life bowlers face in the IPL and what they need to bounce back in the hostile situation they find themselves in</div>,
# ...
